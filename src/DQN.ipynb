# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from rl.agents import DQNAgent
import gym
from gym import spaces
import numpy as np
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.models import clone_model as model_from_config
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from rl.agents import DQNAgent
from rl.policy import EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
import os
import time

# %%
years_files = {
    # 2021: "../Data/merged_2021.xlsx",
    2022: "../Data/merged_2022.xlsx",
    2023: "../Data/merged_2023.xlsx"
}
dfs = []

for year, file_path in years_files.items():
    df = pd.read_excel(file_path, engine='openpyxl')
    df['Year'] = year
    dfs.append(df)

data = pd.concat(dfs, ignore_index=True)
pop_data = pd.read_excel('../Data/state_level_population_projection_wide_xgboost.xlsx')
pop_data_melted = pop_data.melt(
    id_vars=['Variant', 'Variant Description', 'Year', 'Age'],
    value_vars=['Baden-Württemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
               'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen',
               'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen',
               'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen'],
    var_name='state',
    value_name='population'
)
merged_data_population = pd.merge(
    data,
    pop_data_melted,
    left_on=['state', 'Year'],
    right_on=['state', 'Year'],
    how='left'
)

# %%
label_encoders = {}
categorical_cols = ['state', 'MDC', 'Age']
for col in categorical_cols:
    le = LabelEncoder()
    merged_data_population[col + '_encoded'] = le.fit_transform(merged_data_population[col].astype(str))
    label_encoders[col] = le  # Save encoders for later use
# Normalize numerical columns (e.g., 'total_patients')
scaler = StandardScaler()
numerical_cols = merged_data_population.columns.difference(['state', 'MDC','Variant','Variant Description','Fachabteilung', 'Sekundär','state_encoded','MDC_encoded','Land_x','Land_y'])
numerical_cols = [str(col) for col in numerical_cols]
merged_data_population[numerical_cols] = scaler.fit_transform(merged_data_population[numerical_cols])

# %%
merged_data_population[merged_data_population.select_dtypes(include='number').columns] = merged_data_population.select_dtypes(include='number').fillna(0)
merged_data_population[merged_data_population.select_dtypes(include='object').columns] = merged_data_population.select_dtypes(include='object').fillna("unknown")

# %%
state_columns = []
state_columns.extend(numerical_cols)
state_columns.extend(['state_encoded','total_patients'])
len(state_columns)
# Out:
# 200

# %%
from mdc_mapping import mdc_to_fachabteilung
class ReshapeProcessor(Processor):
    def process_state_batch(self, state_batch):
        # Remove the extra dimension: (batch, 1, 2) → (batch, 2)
        return np.squeeze(state_batch, axis=1)

class HospitalEnv(gym.Env):
    def __init__(self, data):
        super(HospitalEnv, self).__init__()
        self.data = data
        self.num_beds = 6
        self.mdc_to_fachabteilung = mdc_to_fachabteilung
        self.state_size = 200  # patients, state
        self.observation_space = spaces.Box(low=0, high=1, shape=(self.state_size,), dtype=np.float32)
        self.mdc_list = list(mdc_to_fachabteilung.keys())
        self.action_space = spaces.Discrete(len(self.mdc_list) * self.num_beds)  # n_depts * beds allowed to re allocate
        self.mdc_to_index = {mdc: idx for idx, mdc in enumerate(self.mdc_list)}
        self.index_to_mdc = {idx: mdc for mdc, idx in self.mdc_to_index.items()}
        self.dept_columns = [col for col in data.columns if col.startswith(('0'))]
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(state_columns),), dtype=np.float32
        )
        self.label_encoders = label_encoders


    def decode_action(self, action):
        mdc = action // self.num_beds
        beds = action % self.num_beds
        return mdc, beds

    def _add_beds(self):
        """Adds 10 beds to the most overcrowded department."""
        utilization = self.current_patient[self.dept_columns] / self.current_patient[self.dept_columns].max()
        worst_dept = self.dept_columns[np.argmax(utilization)]
        self.current_patient[worst_dept] += 10
        self.current_patient['INSG_x'] += 10

    def _get_state(self):
        # Extract ONLY the two features we need
        # print(self.current_patient[numerical_cols])
        out = self.current_patient[state_columns].values.flatten()

        return out

    def _calculate_reward(self, old_state,action):

        mdc_index, _ = self.decode_action(action)
        mdc_label = self.label_encoders["MDC"].inverse_transform([mdc_index])[0]
        mapped_depts = mdc_to_fachabteilung.get(mdc_label, {})
        relevant_depts = mapped_depts.get("Fachabteilung", []) + mapped_depts.get("Sekundär", [])

        current_patients = self.current_patient['total_patients'].values[0]
        bed_values = self.current_patient[self.dept_columns].values.flatten()

        bed_ratios = bed_values / (current_patients + 1e-6)
        # Penalty for overcrowding (patients > beds)
        overcrowding_penalty = np.sum(np.where(bed_ratios < 1, 1 - bed_ratios, 0))

        balance_score = (np.mean(bed_ratios)) / (np.std(bed_ratios) + 1e-6)
        balance_reward = np.clip(balance_score, 0, 10) # Avoid division by zero
        # print(balance_reward)

        target_depts = set(relevant_depts)
        present_depts = set(self.dept_columns)
        matching_depts = target_depts & present_depts
        is_diagnostic_correct = False
        if matching_depts:
            is_diagnostic_correct = True

        # correct_mdc = self.current_patient['MDC_encoded'].values[0]
        diagnostic_reward = 1 if is_diagnostic_correct else -5
        total_reward = (
        0.7 * balance_reward +
        0.3 * diagnostic_reward -
        overcrowding_penalty      # Penalty (unweighted, absolute)
        )
        return float(total_reward)

    def reset(self):
        # Randomly select a patient case
        self.current_patient = self.data.sample(1)
        return self._get_state()

    def _reallocate_beds(self, mdc_index, beds):
        mdc_label = self.label_encoders["MDC"].inverse_transform([mdc_index])[0]
        mapping = mdc_to_fachabteilung.get(mdc_label, {})
        fach = mapping.get("Fachabteilung", [])
        sek = mapping.get("Sekundär", [])
        target_depts = list(set(fach + sek))
        present_depts = [d for d in target_depts if d in self.dept_columns]

        if len(present_depts) < 2 or beds == 0:
            return

        util = self.current_patient[present_depts].values.flatten()
        from_dept = present_depts[np.argmax(util)]
        to_dept = present_depts[np.argmin(util)]

        self.current_patient[from_dept] = max(0, self.current_patient[from_dept] - beds)
        self.current_patient[to_dept] += beds




    def step(self, action):
        old_state = self._get_state()
        mdc_index, beds_to_move = self.decode_action(action)
        self._reallocate_beds(mdc_index, beds_to_move)
        reward = self._calculate_reward(old_state, action)
        done = True
        return self.reset(), reward, done, {}

# %%
from rl.callbacks import Callback
import tensorflow as tf
class CustomTensorBoardCallback(Callback):
    def __init__(self, log_dir="./logs/"):
        os.makedirs(log_dir, exist_ok=True)
        self.writer = tf.summary.create_file_writer(log_dir)
        self.step = 0
        self.episode_rewards = []
        self.episode_steps = []

    def on_episode_begin(self, episode, logs={}):
        self.episode_reward = 0
        self.episode_step = 0

    def on_episode_end(self, episode, logs={}):
        self.episode_rewards.append(self.episode_reward)
        self.episode_steps.append(self.episode_step)

        print(f"Episode {episode + 1} — Reward: {self.episode_reward:.2f}, Length: {self.episode_step}")

    def on_step_end(self, step, logs={}):
        self.step += 1
        with self.writer.as_default():
            if 'reward' in logs:
                tf.summary.scalar('reward', logs['reward'], step=self.step)
            if 'loss' in logs:
                tf.summary.scalar('loss', logs['loss'], step=self.step)
            self.writer.flush()

# %%
import warnings
mdc_list = list(mdc_to_fachabteilung.keys())
policy = EpsGreedyQPolicy()
memory = SequentialMemory(limit=50000, window_length=1)
model = Sequential([
    Dense(128, activation='relu', input_shape=(200,)),
    Dense(128, activation='relu'),
    Dense(len(mdc_list) * 6, activation='linear')  #Number of distinct departments * number_beds
])
model.compile(optimizer='adam', loss='mse')
# Add the processor to your agent
agent = DQNAgent(
    model=model,
    policy=policy,
    memory=memory,
    nb_steps_warmup=100,
    nb_actions=len(mdc_list) * 6,
    batch_size=32,
    enable_double_dqn=True,
    processor=ReshapeProcessor()  # Fixes shape issues
)

agent.compile(optimizer='adam')

# Train the agent
env = HospitalEnv(merged_data_population)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    agent.fit(env, nb_steps=1000, visualize=False, callbacks=[CustomTensorBoardCallback()])
# Out:
# Training for 1000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 40:41 - reward: -37.4579Episode 1 — Reward: 0.00, Length: 0
# Episode 2 — Reward: 0.00, Length: 0
#     3/10000 [..............................] - ETA: 4:40 - reward: -40.3367 Episode 3 — Reward: 0.00, Length: 0
# Episode 4 — Reward: 0.00, Length: 0
#     5/10000 [..............................] - ETA: 5:05 - reward: -34.3219Episode 5 — Reward: 0.00, Length: 0
# Episode 6 — Reward: 0.00, Length: 0
#     7/10000 [..............................] - ETA: 5:01 - reward: -38.0332Episode 7 — Reward: 0.00, Length: 0
# Episode 8 — Reward: 0.00, Length: 0
#     9/10000 [..............................] - ETA: 4:58 - reward: -37.7730Episode 9 — Reward: 0.00, Length: 0
# Episode 10 — Reward: 0.00, Length: 0
#    11/10000 [..............................] - ETA: 4:59 - reward: -61.7946Episode 11 — Reward: 0.00, Length: 0
# Episode 12 — Reward: 0.00, Length: 0
#    13/10000 [..............................] - ETA: 4:57 - reward: -57.1576Episode 13 — Reward: 0.00, Length: 0
#    14/10000 [..............................] - ETA: 7:59 - reward: -54.8809Episode 14 — Reward: 0.00, Length: 0
# Episode 15 — Reward: 0.00, Length: 0
# Episode 16 — Reward: 0.00, Length: 0
#    17/10000 [..............................] - ETA: 7:12 - reward: -151.7850Episode 17 — Reward: 0.00, Length: 0
# Episode 18 — Reward: 0.00, Length: 0
# Episode 19 — Reward: 0.00, Length: 0
#    20/10000 [..............................] - ETA: 6:41 - reward: -136.6298Episode 20 — Reward: 0.00, Length: 0
# Episode 21 — Reward: 0.00, Length: 0
# Episode 22 — Reward: 0.00, Length: 0
#    23/10000 [..............................] - ETA: 6:20 - reward: -123.1859Episode 23 — Reward: 0.00, Length: 0
# Episode 24 — Reward: 0.00, Length: 0
# Episode 25 — Reward: 0.00, Length: 0
#    26/10000 [..............................] - ETA: 6:03 - reward: -111.0521Episode 26 — Reward: 0.00, Length: 0
# Episode 27 — Reward: 0.00, Length: 0
# Episode 28 — Reward: 0.00, Length: 0
#    29/10000 [..............................] - ETA: 5:51 - reward: -104.3981Episode 29 — Reward: 0.00, Length: 0
# Episode 30 — Reward: 0.00, Length: 0
# Episode 31 — Reward: 0.00, Length: 0
#    32/10000 [..............................] - ETA: 5:41 - reward: -101.3387Episode 32 — Reward: 0.00, Length: 0
# Episode 33 — Reward: 0.00, Length: 0
# Episode 34 — Reward: 0.00, Length: 0
#    35/10000 [..............................] - ETA: 5:33 - reward: -95.1127 Episode 35 — Reward: 0.00, Length: 0
# Episode 36 — Reward: 0.00, Length: 0
#    37/10000 [..............................] - ETA: 5:31 - reward: -91.5808Episode 37 — Reward: 0.00, Length: 0
# Episode 38 — Reward: 0.00, Length: 0
# Episode 39 — Reward: 0.00, Length: 0
#    40/10000 [..............................] - ETA: 5:25 - reward: -88.4224Episode 40 — Reward: 0.00, Length: 0
# Episode 41 — Reward: 0.00, Length: 0
# Episode 42 — Reward: 0.00, Length: 0
#    43/10000 [..............................] - ETA: 5:19 - reward: -85.2786Episode 43 — Reward: 0.00, Length: 0
# Episode 44 — Reward: 0.00, Length: 0
# Episode 45 — Reward: 0.00, Length: 0
#    46/10000 [..............................] - ETA: 5:13 - reward: -82.3713Episode 46 — Reward: 0.00, Length: 0
# Episode 47 — Reward: 0.00, Length: 0
# Episode 48 — Reward: 0.00, Length: 0
#    49/10000 [..............................] - ETA: 5:08 - reward: -81.8645Episode 49 — Reward: 0.00, Length: 0
# Episode 50 — Reward: 0.00, Length: 0
# Episode 51 — Reward: 0.00, Length: 0
#    52/10000 [..............................] - ETA: 5:03 - reward: -80.7210Episode 52 — Reward: 0.00, Length: 0
# Episode 53 — Reward: 0.00, Length: 0
# Episode 54 — Reward: 0.00, Length: 0
#    55/10000 [..............................] - ETA: 4:59 - reward: -77.6913Episode 55 — Reward: 0.00, Length: 0
# Episode 56 — Reward: 0.00, Length: 0
# Episode 57 — Reward: 0.00, Length: 0
#    58/10000 [..............................] - ETA: 4:56 - reward: -76.8109Episode 58 — Reward: 0.00, Length: 0
# Episode 59 — Reward: 0.00, Length: 0
# Episode 60 — Reward: 0.00, Length: 0
#    61/10000 [..............................] - ETA: 4:54 - reward: -74.7501Episode 61 — Reward: 0.00, Length: 0
# Episode 62 — Reward: 0.00, Length: 0
#    63/10000 [..............................] - ETA: 4:52 - reward: -73.9409Episode 63 — Reward: 0.00, Length: 0
# Episode 64 — Reward: 0.00, Length: 0
#    65/10000 [..............................] - ETA: 4:51 - reward: -75.3576Episode 65 — Reward: 0.00, Length: 0
# Episode 66 — Reward: 0.00, Length: 0
#    67/10000 [..............................] - ETA: 4:50 - reward: -74.7945Episode 67 — Reward: 0.00, Length: 0
# Episode 68 — Reward: 0.00, Length: 0
#    69/10000 [..............................] - ETA: 4:50 - reward: -75.0622Episode 69 — Reward: 0.00, Length: 0
# Episode 70 — Reward: 0.00, Length: 0
#    71/10000 [..............................] - ETA: 4:52 - reward: -73.4619Episode 71 — Reward: 0.00, Length: 0
# Episode 72 — Reward: 0.00, Length: 0
#    73/10000 [..............................] - ETA: 4:54 - reward: -72.3869Episode 73 — Reward: 0.00, Length: 0
# Episode 74 — Reward: 0.00, Length: 0
#    75/10000 [..............................] - ETA: 4:56 - reward: -74.1072Episode 75 — Reward: 0.00, Length: 0
# Episode 76 — Reward: 0.00, Length: 0
#    77/10000 [..............................] - ETA: 4:55 - reward: -73.4043Episode 77 — Reward: 0.00, Length: 0
# Episode 78 — Reward: 0.00, Length: 0
#    79/10000 [..............................] - ETA: 4:55 - reward: -72.3550Episode 79 — Reward: 0.00, Length: 0
# Episode 80 — Reward: 0.00, Length: 0
#    81/10000 [..............................] - ETA: 4:55 - reward: -71.6817Episode 81 — Reward: 0.00, Length: 0
# Episode 82 — Reward: 0.00, Length: 0
#    83/10000 [..............................] - ETA: 4:55 - reward: -70.7561Episode 83 — Reward: 0.00, Length: 0
# Episode 84 — Reward: 0.00, Length: 0
#    85/10000 [..............................] - ETA: 4:56 - reward: -69.9372Episode 85 — Reward: 0.00, Length: 0
# Episode 86 — Reward: 0.00, Length: 0
#    87/10000 [..............................] - ETA: 4:56 - reward: -68.8404Episode 87 — Reward: 0.00, Length: 0
# Episode 88 — Reward: 0.00, Length: 0
#    89/10000 [..............................] - ETA: 4:57 - reward: -67.7853Episode 89 — Reward: 0.00, Length: 0
# Episode 90 — Reward: 0.00, Length: 0
#    91/10000 [..............................] - ETA: 4:56 - reward: -68.5253Episode 91 — Reward: 0.00, Length: 0
# Episode 92 — Reward: 0.00, Length: 0
#    93/10000 [..............................] - ETA: 4:57 - reward: -71.0935Episode 93 — Reward: 0.00, Length: 0
# Episode 94 — Reward: 0.00, Length: 0
#    95/10000 [..............................] - ETA: 4:57 - reward: -70.3341Episode 95 — Reward: 0.00, Length: 0
# Episode 96 — Reward: 0.00, Length: 0
#    97/10000 [..............................] - ETA: 4:57 - reward: -69.6428Episode 97 — Reward: 0.00, Length: 0
# Episode 98 — Reward: 0.00, Length: 0
#    99/10000 [..............................] - ETA: 4:57 - reward: -68.8535Episode 99 — Reward: 0.00, Length: 0
# Episode 100 — Reward: 0.00, Length: 0
#   101/10000 [..............................] - ETA: 4:57 - reward: -67.9586Episode 101 — Reward: 0.00, Length: 0
#   102/10000 [..............................] - ETA: 6:50 - reward: -67.5890Episode 102 — Reward: 0.00, Length: 0
#   103/10000 [..............................] - ETA: 7:00 - reward: -67.4161Episode 103 — Reward: 0.00, Length: 0
#   104/10000 [..............................] - ETA: 7:32 - reward: -67.1714Episode 104 — Reward: 0.00, Length: 0
#   105/10000 [..............................] - ETA: 7:40 - reward: -67.0171Episode 105 — Reward: 0.00, Length: 0
#   106/10000 [..............................] - ETA: 7:49 - reward: -66.7358Episode 106 — Reward: 0.00, Length: 0
#   107/10000 [..............................] - ETA: 8:03 - reward: -66.4527Episode 107 — Reward: 0.00, Length: 0
#   108/10000 [..............................] - ETA: 8:12 - reward: -66.1618Episode 108 — Reward: 0.00, Length: 0
#   109/10000 [..............................] - ETA: 8:20 - reward: -65.7085Episode 109 — Reward: 0.00, Length: 0
#   110/10000 [..............................] - ETA: 8:28 - reward: -65.5223Episode 110 — Reward: 0.00, Length: 0
#   111/10000 [..............................] - ETA: 8:36 - reward: -65.0597Episode 111 — Reward: 0.00, Length: 0
#   112/10000 [..............................] - ETA: 8:43 - reward: -64.6154Episode 112 — Reward: 0.00, Length: 0
#   113/10000 [..............................] - ETA: 8:50 - reward: -64.5665Episode 113 — Reward: 0.00, Length: 0
#   114/10000 [..............................] - ETA: 8:57 - reward: -64.9846Episode 114 — Reward: 0.00, Length: 0
#   115/10000 [..............................] - ETA: 9:03 - reward: -67.0884Episode 115 — Reward: 0.00, Length: 0
#   116/10000 [..............................] - ETA: 9:19 - reward: -66.9683Episode 116 — Reward: 0.00, Length: 0
#   117/10000 [..............................] - ETA: 9:42 - reward: -66.8645Episode 117 — Reward: 0.00, Length: 0
#   118/10000 [..............................] - ETA: 9:55 - reward: -66.5514Episode 118 — Reward: 0.00, Length: 0
#   119/10000 [..............................] - ETA: 10:07 - reward: -66.2184Episode 119 — Reward: 0.00, Length: 0
#   120/10000 [..............................] - ETA: 10:19 - reward: -65.9979Episode 120 — Reward: 0.00, Length: 0
#   121/10000 [..............................] - ETA: 10:38 - reward: -65.5701Episode 121 — Reward: 0.00, Length: 0
#   122/10000 [..............................] - ETA: 10:53 - reward: -65.3304Episode 122 — Reward: 0.00, Length: 0
#   123/10000 [..............................] - ETA: 11:05 - reward: -64.9277Episode 123 — Reward: 0.00, Length: 0
#   124/10000 [..............................] - ETA: 11:17 - reward: -65.1337Episode 124 — Reward: 0.00, Length: 0
#   125/10000 [..............................] - ETA: 11:33 - reward: -65.6189Episode 125 — Reward: 0.00, Length: 0
#   126/10000 [..............................] - ETA: 11:41 - reward: -65.4083Episode 126 — Reward: 0.00, Length: 0
#   127/10000 [..............................] - ETA: 11:46 - reward: -65.2095Episode 127 — Reward: 0.00, Length: 0
#   128/10000 [..............................] - ETA: 11:51 - reward: -64.9380Episode 128 — Reward: 0.00, Length: 0
#   129/10000 [..............................] - ETA: 11:56 - reward: -65.0697Episode 129 — Reward: 0.00, Length: 0
#   130/10000 [..............................] - ETA: 12:01 - reward: -64.7993Episode 130 — Reward: 0.00, Length: 0
#   131/10000 [..............................] - ETA: 12:12 - reward: -64.6548Episode 131 — Reward: 0.00, Length: 0
#   132/10000 [..............................] - ETA: 12:19 - reward: -64.3702Episode 132 — Reward: 0.00, Length: 0
#   133/10000 [..............................] - ETA: 12:24 - reward: -64.1228Episode 133 — Reward: 0.00, Length: 0
#   134/10000 [..............................] - ETA: 12:29 - reward: -64.7064Episode 134 — Reward: 0.00, Length: 0
#   135/10000 [..............................] - ETA: 12:33 - reward: -64.4491Episode 135 — Reward: 0.00, Length: 0
#   136/10000 [..............................] - ETA: 12:38 - reward: -64.3151Episode 136 — Reward: 0.00, Length: 0
#   137/10000 [..............................] - ETA: 12:43 - reward: -64.6352Episode 137 — Reward: 0.00, Length: 0
#   138/10000 [..............................] - ETA: 12:55 - reward: -64.4589Episode 138 — Reward: 0.00, Length: 0
#   139/10000 [..............................] - ETA: 13:00 - reward: -64.2285Episode 139 — Reward: 0.00, Length: 0
#   140/10000 [..............................] - ETA: 13:04 - reward: -63.9492Episode 140 — Reward: 0.00, Length: 0
#   141/10000 [..............................] - ETA: 13:08 - reward: -63.6371Episode 141 — Reward: 0.00, Length: 0
#   142/10000 [..............................] - ETA: 13:12 - reward: -63.3136Episode 142 — Reward: 0.00, Length: 0
#   143/10000 [..............................] - ETA: 13:16 - reward: -63.0072Episode 143 — Reward: 0.00, Length: 0
#   144/10000 [..............................] - ETA: 13:27 - reward: -62.8496Episode 144 — Reward: 0.00, Length: 0
#   145/10000 [..............................] - ETA: 13:32 - reward: -62.5237Episode 145 — Reward: 0.00, Length: 0
#   146/10000 [..............................] - ETA: 13:36 - reward: -62.6164Episode 146 — Reward: 0.00, Length: 0
#   147/10000 [..............................] - ETA: 13:39 - reward: -62.4473Episode 147 — Reward: 0.00, Length: 0
#   148/10000 [..............................] - ETA: 13:43 - reward: -62.2368Episode 148 — Reward: 0.00, Length: 0
#   149/10000 [..............................] - ETA: 13:46 - reward: -62.7133Episode 149 — Reward: 0.00, Length: 0
#   150/10000 [..............................] - ETA: 13:50 - reward: -62.5088Episode 150 — Reward: 0.00, Length: 0
#   151/10000 [..............................] - ETA: 13:58 - reward: -62.3691Episode 151 — Reward: 0.00, Length: 0
#   152/10000 [..............................] - ETA: 14:02 - reward: -62.2183Episode 152 — Reward: 0.00, Length: 0
#   153/10000 [..............................] - ETA: 14:05 - reward: -62.2583Episode 153 — Reward: 0.00, Length: 0
#   154/10000 [..............................] - ETA: 14:09 - reward: -62.0229Episode 154 — Reward: 0.00, Length: 0
#   155/10000 [..............................] - ETA: 14:12 - reward: -61.9401Episode 155 — Reward: 0.00, Length: 0
#   156/10000 [..............................] - ETA: 14:16 - reward: -61.6415Episode 156 — Reward: 0.00, Length: 0
#   157/10000 [..............................] - ETA: 14:26 - reward: -61.4979Episode 157 — Reward: 0.00, Length: 0
#   158/10000 [..............................] - ETA: 14:29 - reward: -61.1942Episode 158 — Reward: 0.00, Length: 0
#   159/10000 [..............................] - ETA: 14:33 - reward: -61.1438Episode 159 — Reward: 0.00, Length: 0
#   160/10000 [..............................] - ETA: 14:36 - reward: -61.2250Episode 160 — Reward: 0.00, Length: 0
#   161/10000 [..............................] - ETA: 14:40 - reward: -61.5766Episode 161 — Reward: 0.00, Length: 0
#   162/10000 [..............................] - ETA: 14:43 - reward: -61.2904Episode 162 — Reward: 0.00, Length: 0
#   163/10000 [..............................] - ETA: 14:53 - reward: -61.1676Episode 163 — Reward: 0.00, Length: 0
#   164/10000 [..............................] - ETA: 14:57 - reward: -60.9559Episode 164 — Reward: 0.00, Length: 0
#   165/10000 [..............................] - ETA: 15:00 - reward: -60.8606Episode 165 — Reward: 0.00, Length: 0
#   166/10000 [..............................] - ETA: 15:03 - reward: -60.7149Episode 166 — Reward: 0.00, Length: 0
#   167/10000 [..............................] - ETA: 15:06 - reward: -60.4435Episode 167 — Reward: 0.00, Length: 0
#   168/10000 [..............................] - ETA: 15:10 - reward: -60.5365Episode 168 — Reward: 0.00, Length: 0
#   169/10000 [..............................] - ETA: 15:19 - reward: -60.3270Episode 169 — Reward: 0.00, Length: 0
#   170/10000 [..............................] - ETA: 15:22 - reward: -60.1250Episode 170 — Reward: 0.00, Length: 0
#   171/10000 [..............................] - ETA: 15:25 - reward: -60.3528Episode 171 — Reward: 0.00, Length: 0
#   172/10000 [..............................] - ETA: 15:29 - reward: -60.2202Episode 172 — Reward: 0.00, Length: 0
#   173/10000 [..............................] - ETA: 15:32 - reward: -60.5221Episode 173 — Reward: 0.00, Length: 0
#   174/10000 [..............................] - ETA: 15:35 - reward: -60.3326Episode 174 — Reward: 0.00, Length: 0
#   175/10000 [..............................] - ETA: 15:41 - reward: -60.8662Episode 175 — Reward: 0.00, Length: 0
#   176/10000 [..............................] - ETA: 15:45 - reward: -60.7122Episode 176 — Reward: 0.00, Length: 0
#   177/10000 [..............................] - ETA: 15:49 - reward: -61.5158Episode 177 — Reward: 0.00, Length: 0
#   178/10000 [..............................] - ETA: 15:52 - reward: -61.3396Episode 178 — Reward: 0.00, Length: 0
#   179/10000 [..............................] - ETA: 15:56 - reward: -61.1585Episode 179 — Reward: 0.00, Length: 0
#   180/10000 [..............................] - ETA: 15:59 - reward: -61.1820Episode 180 — Reward: 0.00, Length: 0
#   181/10000 [..............................] - ETA: 16:06 - reward: -61.1492Episode 181 — Reward: 0.00, Length: 0
#   182/10000 [..............................] - ETA: 16:10 - reward: -61.0152Episode 182 — Reward: 0.00, Length: 0
#   183/10000 [..............................] - ETA: 16:13 - reward: -60.8267Episode 183 — Reward: 0.00, Length: 0
#   184/10000 [..............................] - ETA: 16:16 - reward: -62.1029Episode 184 — Reward: 0.00, Length: 0
#   185/10000 [..............................] - ETA: 16:18 - reward: -61.9194Episode 185 — Reward: 0.00, Length: 0
#   186/10000 [..............................] - ETA: 16:21 - reward: -61.7114Episode 186 — Reward: 0.00, Length: 0
#   187/10000 [..............................] - ETA: 16:32 - reward: -62.4907Episode 187 — Reward: 0.00, Length: 0
#   188/10000 [..............................] - ETA: 16:39 - reward: -62.4621Episode 188 — Reward: 0.00, Length: 0
#   189/10000 [..............................] - ETA: 16:46 - reward: -62.3112Episode 189 — Reward: 0.00, Length: 0
#   190/10000 [..............................] - ETA: 16:53 - reward: -62.0643Episode 190 — Reward: 0.00, Length: 0
#   191/10000 [..............................] - ETA: 17:06 - reward: -61.9948Episode 191 — Reward: 0.00, Length: 0
#   192/10000 [..............................] - ETA: 17:12 - reward: -62.2082Episode 192 — Reward: 0.00, Length: 0
#   193/10000 [..............................] - ETA: 17:19 - reward: -62.4491Episode 193 — Reward: 0.00, Length: 0
#   194/10000 [..............................] - ETA: 17:28 - reward: -62.5980Episode 194 — Reward: 0.00, Length: 0
#   195/10000 [..............................] - ETA: 17:40 - reward: -62.4840Episode 195 — Reward: 0.00, Length: 0
#   196/10000 [..............................] - ETA: 17:42 - reward: -62.4471Episode 196 — Reward: 0.00, Length: 0
#   197/10000 [..............................] - ETA: 17:44 - reward: -62.2591Episode 197 — Reward: 0.00, Length: 0
#   198/10000 [..............................] - ETA: 17:46 - reward: -62.0130Episode 198 — Reward: 0.00, Length: 0
#   199/10000 [..............................] - ETA: 18:00 - reward: -61.9483Episode 199 — Reward: 0.00, Length: 0
#   200/10000 [..............................] - ETA: 18:03 - reward: -61.7791Episode 200 — Reward: 0.00, Length: 0
#   201/10000 [..............................] - ETA: 18:05 - reward: -61.6398Episode 201 — Reward: 0.00, Length: 0
#   202/10000 [..............................] - ETA: 18:07 - reward: -61.5291Episode 202 — Reward: 0.00, Length: 0
#   203/10000 [..............................] - ETA: 18:09 - reward: -61.5640Episode 203 — Reward: 0.00, Length: 0
#   204/10000 [..............................] - ETA: 18:11 - reward: -61.3417Episode 204 — Reward: 0.00, Length: 0
#   205/10000 [..............................] - ETA: 18:17 - reward: -61.1747Episode 205 — Reward: 0.00, Length: 0
#   206/10000 [..............................] - ETA: 18:19 - reward: -61.0121Episode 206 — Reward: 0.00, Length: 0
#   207/10000 [..............................] - ETA: 18:22 - reward: -61.4625Episode 207 — Reward: 0.00, Length: 0
#   208/10000 [..............................] - ETA: 18:24 - reward: -61.4107Episode 208 — Reward: 0.00, Length: 0
#   209/10000 [..............................] - ETA: 18:26 - reward: -61.2416Episode 209 — Reward: 0.00, Length: 0
#   210/10000 [..............................] - ETA: 18:32 - reward: -61.2417Episode 210 — Reward: 0.00, Length: 0
#   211/10000 [..............................] - ETA: 18:34 - reward: -88.5303Episode 211 — Reward: 0.00, Length: 0
#   212/10000 [..............................] - ETA: 18:37 - reward: -88.6529Episode 212 — Reward: 0.00, Length: 0
#   213/10000 [..............................] - ETA: 18:39 - reward: -88.5315Episode 213 — Reward: 0.00, Length: 0
#   214/10000 [..............................] - ETA: 18:41 - reward: -88.2437Episode 214 — Reward: 0.00, Length: 0
#   215/10000 [..............................] - ETA: 18:46 - reward: -87.9794Episode 215 — Reward: 0.00, Length: 0
#   216/10000 [..............................] - ETA: 18:49 - reward: -87.7098Episode 216 — Reward: 0.00, Length: 0
#   217/10000 [..............................] - ETA: 18:51 - reward: -87.5230Episode 217 — Reward: 0.00, Length: 0
#   218/10000 [..............................] - ETA: 18:53 - reward: -87.6623Episode 218 — Reward: 0.00, Length: 0
#   219/10000 [..............................] - ETA: 18:55 - reward: -87.4050Episode 219 — Reward: 0.00, Length: 0
#   220/10000 [..............................] - ETA: 18:57 - reward: -87.2148Episode 220 — Reward: 0.00, Length: 0
#   221/10000 [..............................] - ETA: 19:02 - reward: -87.1811Episode 221 — Reward: 0.00, Length: 0
#   222/10000 [..............................] - ETA: 19:05 - reward: -86.9922Episode 222 — Reward: 0.00, Length: 0
#   223/10000 [..............................] - ETA: 19:07 - reward: -86.9409Episode 223 — Reward: 0.00, Length: 0
#   224/10000 [..............................] - ETA: 19:09 - reward: -86.6822Episode 224 — Reward: 0.00, Length: 0
#   225/10000 [..............................] - ETA: 19:11 - reward: -86.7944Episode 225 — Reward: 0.00, Length: 0
#   226/10000 [..............................] - ETA: 19:13 - reward: -87.1298Episode 226 — Reward: 0.00, Length: 0
#   227/10000 [..............................] - ETA: 19:17 - reward: -86.9976Episode 227 — Reward: 0.00, Length: 0
#   228/10000 [..............................] - ETA: 19:19 - reward: -86.7395Episode 228 — Reward: 0.00, Length: 0
#   229/10000 [..............................] - ETA: 19:20 - reward: -86.5188Episode 229 — Reward: 0.00, Length: 0
#   230/10000 [..............................] - ETA: 19:23 - reward: -86.3184Episode 230 — Reward: 0.00, Length: 0
#   231/10000 [..............................] - ETA: 19:25 - reward: -86.0806Episode 231 — Reward: 0.00, Length: 0
#   232/10000 [..............................] - ETA: 19:31 - reward: -85.8404Episode 232 — Reward: 0.00, Length: 0
#   233/10000 [..............................] - ETA: 19:33 - reward: -85.7898Episode 233 — Reward: 0.00, Length: 0
#   234/10000 [..............................] - ETA: 19:36 - reward: -85.6716Episode 234 — Reward: 0.00, Length: 0
#   235/10000 [..............................] - ETA: 19:38 - reward: -85.4403Episode 235 — Reward: 0.00, Length: 0
#   236/10000 [..............................] - ETA: 19:41 - reward: -85.2370Episode 236 — Reward: 0.00, Length: 0
#   237/10000 [..............................] - ETA: 19:47 - reward: -85.4317Episode 237 — Reward: 0.00, Length: 0
#   238/10000 [..............................] - ETA: 19:49 - reward: -85.3394Episode 238 — Reward: 0.00, Length: 0
#   239/10000 [..............................] - ETA: 19:51 - reward: -85.0915Episode 239 — Reward: 0.00, Length: 0
#   240/10000 [..............................] - ETA: 19:54 - reward: -84.9371Episode 240 — Reward: 0.00, Length: 0
#   241/10000 [..............................] - ETA: 19:57 - reward: -84.8179Episode 241 — Reward: 0.00, Length: 0
#   242/10000 [..............................] - ETA: 20:02 - reward: -84.6475Episode 242 — Reward: 0.00, Length: 0
#   243/10000 [..............................] - ETA: 20:04 - reward: -85.1812Episode 243 — Reward: 0.00, Length: 0
#   244/10000 [..............................] - ETA: 20:06 - reward: -84.9515Episode 244 — Reward: 0.00, Length: 0
#   245/10000 [..............................] - ETA: 20:08 - reward: -84.7487Episode 245 — Reward: 0.00, Length: 0
#   246/10000 [..............................] - ETA: 20:11 - reward: -84.8402Episode 246 — Reward: 0.00, Length: 0
#   247/10000 [..............................] - ETA: 20:12 - reward: -84.6811Episode 247 — Reward: 0.00, Length: 0
#   248/10000 [..............................] - ETA: 20:16 - reward: -84.4482Episode 248 — Reward: 0.00, Length: 0
#   249/10000 [..............................] - ETA: 20:19 - reward: -84.2919Episode 249 — Reward: 0.00, Length: 0
#   250/10000 [..............................] - ETA: 20:25 - reward: -84.0315Episode 250 — Reward: 0.00, Length: 0
#   251/10000 [..............................] - ETA: 20:30 - reward: -84.5232Episode 251 — Reward: 0.00, Length: 0
#   252/10000 [..............................] - ETA: 20:41 - reward: -84.8673Episode 252 — Reward: 0.00, Length: 0
#   253/10000 [..............................] - ETA: 20:46 - reward: -84.6118Episode 253 — Reward: 0.00, Length: 0
#   254/10000 [..............................] - ETA: 20:51 - reward: -84.9856Episode 254 — Reward: 0.00, Length: 0
#   255/10000 [..............................] - ETA: 20:57 - reward: -88.4863Episode 255 — Reward: 0.00, Length: 0
#   256/10000 [..............................] - ETA: 21:02 - reward: -88.2975Episode 256 — Reward: 0.00, Length: 0
#   257/10000 [..............................] - ETA: 21:04 - reward: -88.0596Episode 257 — Reward: 0.00, Length: 0
#   258/10000 [..............................] - ETA: 21:06 - reward: -87.8380Episode 258 — Reward: 0.00, Length: 0
#   259/10000 [..............................] - ETA: 21:10 - reward: -87.6202Episode 259 — Reward: 0.00, Length: 0
#   260/10000 [..............................] - ETA: 21:12 - reward: -87.4488Episode 260 — Reward: 0.00, Length: 0
#   261/10000 [..............................] - ETA: 21:14 - reward: -87.2673Episode 261 — Reward: 0.00, Length: 0
#   262/10000 [..............................] - ETA: 21:15 - reward: -86.9955Episode 262 — Reward: 0.00, Length: 0
#   263/10000 [..............................] - ETA: 21:17 - reward: -86.7286Episode 263 — Reward: 0.00, Length: 0
#   264/10000 [..............................] - ETA: 21:23 - reward: -86.5938Episode 264 — Reward: 0.00, Length: 0
#   265/10000 [..............................] - ETA: 21:24 - reward: -86.3856Episode 265 — Reward: 0.00, Length: 0
#   266/10000 [..............................] - ETA: 21:26 - reward: -86.2504Episode 266 — Reward: 0.00, Length: 0
#   267/10000 [..............................] - ETA: 21:27 - reward: -86.0586Episode 267 — Reward: 0.00, Length: 0
#   268/10000 [..............................] - ETA: 21:29 - reward: -86.6399Episode 268 — Reward: 0.00, Length: 0
#   269/10000 [..............................] - ETA: 21:31 - reward: -86.7845Episode 269 — Reward: 0.00, Length: 0
#   270/10000 [..............................] - ETA: 21:35 - reward: -86.5755Episode 270 — Reward: 0.00, Length: 0
#   271/10000 [..............................] - ETA: 21:36 - reward: -86.3487Episode 271 — Reward: 0.00, Length: 0
#   272/10000 [..............................] - ETA: 21:37 - reward: -86.0877Episode 272 — Reward: 0.00, Length: 0
#   273/10000 [..............................] - ETA: 21:39 - reward: -86.0290Episode 273 — Reward: 0.00, Length: 0
#   274/10000 [..............................] - ETA: 21:41 - reward: -85.9191Episode 274 — Reward: 0.00, Length: 0
#   275/10000 [..............................] - ETA: 21:46 - reward: -85.6992Episode 275 — Reward: 0.00, Length: 0
#   276/10000 [..............................] - ETA: 21:48 - reward: -85.7904Episode 276 — Reward: 0.00, Length: 0
#   277/10000 [..............................] - ETA: 21:49 - reward: -85.8716Episode 277 — Reward: 0.00, Length: 0
#   278/10000 [..............................] - ETA: 21:50 - reward: -85.8534Episode 278 — Reward: 0.00, Length: 0
#   279/10000 [..............................] - ETA: 21:52 - reward: -85.6721Episode 279 — Reward: 0.00, Length: 0
#   280/10000 [..............................] - ETA: 21:56 - reward: -85.4541Episode 280 — Reward: 0.00, Length: 0
#   281/10000 [..............................] - ETA: 21:57 - reward: -85.4206Episode 281 — Reward: 0.00, Length: 0
#   282/10000 [..............................] - ETA: 21:59 - reward: -85.6224Episode 282 — Reward: 0.00, Length: 0
#   283/10000 [..............................] - ETA: 22:00 - reward: -85.4289Episode 283 — Reward: 0.00, Length: 0
#   284/10000 [..............................] - ETA: 22:01 - reward: -85.2477Episode 284 — Reward: 0.00, Length: 0
#   285/10000 [..............................] - ETA: 22:05 - reward: -84.9998Episode 285 — Reward: 0.00, Length: 0
#   286/10000 [..............................] - ETA: 22:07 - reward: -84.8284Episode 286 — Reward: 0.00, Length: 0
#   287/10000 [..............................] - ETA: 22:08 - reward: -84.6420Episode 287 — Reward: 0.00, Length: 0
#   288/10000 [..............................] - ETA: 22:09 - reward: -84.6732Episode 288 — Reward: 0.00, Length: 0
#   289/10000 [..............................] - ETA: 22:11 - reward: -84.4476Episode 289 — Reward: 0.00, Length: 0
#   290/10000 [..............................] - ETA: 22:15 - reward: -84.2478Episode 290 — Reward: 0.00, Length: 0
#   291/10000 [..............................] - ETA: 22:17 - reward: -84.0538Episode 291 — Reward: 0.00, Length: 0
#   292/10000 [..............................] - ETA: 22:18 - reward: -84.0465Episode 292 — Reward: 0.00, Length: 0
#   293/10000 [..............................] - ETA: 22:19 - reward: -83.8974Episode 293 — Reward: 0.00, Length: 0
#   294/10000 [..............................] - ETA: 22:21 - reward: -83.7514Episode 294 — Reward: 0.00, Length: 0
#   295/10000 [..............................] - ETA: 22:24 - reward: -83.5532Episode 295 — Reward: 0.00, Length: 0
#   296/10000 [..............................] - ETA: 22:34 - reward: -83.3507Episode 296 — Reward: 0.00, Length: 0
#   297/10000 [..............................] - ETA: 22:35 - reward: -83.3142Episode 297 — Reward: 0.00, Length: 0
#   298/10000 [..............................] - ETA: 22:36 - reward: -83.3392Episode 298 — Reward: 0.00, Length: 0
#   299/10000 [..............................] - ETA: 22:38 - reward: -83.1598Episode 299 — Reward: 0.00, Length: 0
#   300/10000 [..............................] - ETA: 22:41 - reward: -83.0195Episode 300 — Reward: 0.00, Length: 0
#   301/10000 [..............................] - ETA: 22:43 - reward: -82.8776Episode 301 — Reward: 0.00, Length: 0
#   302/10000 [..............................] - ETA: 22:44 - reward: -82.7038Episode 302 — Reward: 0.00, Length: 0
#   303/10000 [..............................] - ETA: 22:45 - reward: -82.4778Episode 303 — Reward: 0.00, Length: 0
#   304/10000 [..............................] - ETA: 22:46 - reward: -83.2404Episode 304 — Reward: 0.00, Length: 0
#   305/10000 [..............................] - ETA: 22:48 - reward: -83.3193Episode 305 — Reward: 0.00, Length: 0
#   306/10000 [..............................] - ETA: 22:52 - reward: -83.1242Episode 306 — Reward: 0.00, Length: 0
#   307/10000 [..............................] - ETA: 22:56 - reward: -83.3269Episode 307 — Reward: 0.00, Length: 0
#   308/10000 [..............................] - ETA: 23:00 - reward: -83.1483Episode 308 — Reward: 0.00, Length: 0
#   309/10000 [..............................] - ETA: 23:04 - reward: -83.2582Episode 309 — Reward: 0.00, Length: 0
#   310/10000 [..............................] - ETA: 23:08 - reward: -83.1477Episode 310 — Reward: 0.00, Length: 0
#   311/10000 [..............................] - ETA: 23:15 - reward: -83.0076Episode 311 — Reward: 0.00, Length: 0
#   312/10000 [..............................] - ETA: 23:23 - reward: -82.8675Episode 312 — Reward: 0.00, Length: 0
#   313/10000 [..............................] - ETA: 23:27 - reward: -82.6814Episode 313 — Reward: 0.00, Length: 0
#   314/10000 [..............................] - ETA: 23:28 - reward: -83.7345Episode 314 — Reward: 0.00, Length: 0
#   315/10000 [..............................] - ETA: 23:31 - reward: -83.5648Episode 315 — Reward: 0.00, Length: 0
#   316/10000 [..............................] - ETA: 23:33 - reward: -83.4528Episode 316 — Reward: 0.00, Length: 0
#   317/10000 [..............................] - ETA: 23:34 - reward: -83.3140Episode 317 — Reward: 0.00, Length: 0
#   318/10000 [..............................] - ETA: 23:34 - reward: -83.1770Episode 318 — Reward: 0.00, Length: 0
#   319/10000 [..............................] - ETA: 23:36 - reward: -83.0114Episode 319 — Reward: 0.00, Length: 0
#   320/10000 [..............................] - ETA: 23:38 - reward: -82.8552Episode 320 — Reward: 0.00, Length: 0
#   321/10000 [..............................] - ETA: 23:39 - reward: -82.7389Episode 321 — Reward: 0.00, Length: 0
#   322/10000 [..............................] - ETA: 23:41 - reward: -82.5917Episode 322 — Reward: 0.00, Length: 0
#   323/10000 [..............................] - ETA: 23:42 - reward: -82.6725Episode 323 — Reward: 0.00, Length: 0
#   324/10000 [..............................] - ETA: 23:43 - reward: -82.7238Episode 324 — Reward: 0.00, Length: 0
#   325/10000 [..............................] - ETA: 23:47 - reward: -82.6939Episode 325 — Reward: 0.00, Length: 0
#   326/10000 [..............................] - ETA: 23:48 - reward: -82.7102Episode 326 — Reward: 0.00, Length: 0
#   327/10000 [..............................] - ETA: 23:50 - reward: -82.8411Episode 327 — Reward: 0.00, Length: 0
#   328/10000 [..............................] - ETA: 23:51 - reward: -82.7209Episode 328 — Reward: 0.00, Length: 0
#   329/10000 [..............................] - ETA: 23:52 - reward: -82.5226Episode 329 — Reward: 0.00, Length: 0
#   330/10000 [..............................] - ETA: 23:55 - reward: -82.5138Episode 330 — Reward: 0.00, Length: 0
#   331/10000 [..............................] - ETA: 23:56 - reward: -82.3108Episode 331 — Reward: 0.00, Length: 0
#   332/10000 [..............................] - ETA: 23:57 - reward: -82.3084Episode 332 — Reward: 0.00, Length: 0
#   333/10000 [..............................] - ETA: 23:58 - reward: -82.1997Episode 333 — Reward: 0.00, Length: 0
#   334/10000 [>.............................] - ETA: 24:01 - reward: -82.0316Episode 334 — Reward: 0.00, Length: 0
#   335/10000 [>.............................] - ETA: 24:03 - reward: -82.1475Episode 335 — Reward: 0.00, Length: 0
#   336/10000 [>.............................] - ETA: 24:04 - reward: -82.0535Episode 336 — Reward: 0.00, Length: 0
#   337/10000 [>.............................] - ETA: 24:05 - reward: -81.9188Episode 337 — Reward: 0.00, Length: 0
#   338/10000 [>.............................] - ETA: 24:06 - reward: -82.0547Episode 338 — Reward: 0.00, Length: 0
#   339/10000 [>.............................] - ETA: 24:10 - reward: -81.9026Episode 339 — Reward: 0.00, Length: 0
#   340/10000 [>.............................] - ETA: 24:11 - reward: -81.7803Episode 340 — Reward: 0.00, Length: 0
#   341/10000 [>.............................] - ETA: 24:12 - reward: -81.8424Episode 341 — Reward: 0.00, Length: 0
#   342/10000 [>.............................] - ETA: 24:13 - reward: -82.0383Episode 342 — Reward: 0.00, Length: 0
#   343/10000 [>.............................] - ETA: 24:14 - reward: -81.9022Episode 343 — Reward: 0.00, Length: 0
#   344/10000 [>.............................] - ETA: 24:16 - reward: -81.7128Episode 344 — Reward: 0.00, Length: 0
#   345/10000 [>.............................] - ETA: 24:17 - reward: -81.8594Episode 345 — Reward: 0.00, Length: 0
#   346/10000 [>.............................] - ETA: 24:18 - reward: -81.7450Episode 346 — Reward: 0.00, Length: 0
#   347/10000 [>.............................] - ETA: 24:19 - reward: -81.7231Episode 347 — Reward: 0.00, Length: 0
#   348/10000 [>.............................] - ETA: 24:20 - reward: -81.5855Episode 348 — Reward: 0.00, Length: 0
#   349/10000 [>.............................] - ETA: 24:23 - reward: -81.5974Episode 349 — Reward: 0.00, Length: 0
#   350/10000 [>.............................] - ETA: 24:24 - reward: -81.4518Episode 350 — Reward: 0.00, Length: 0
#   351/10000 [>.............................] - ETA: 24:24 - reward: -81.3267Episode 351 — Reward: 0.00, Length: 0
#   352/10000 [>.............................] - ETA: 24:26 - reward: -81.1396Episode 352 — Reward: 0.00, Length: 0
#   353/10000 [>.............................] - ETA: 24:28 - reward: -80.9872Episode 353 — Reward: 0.00, Length: 0
#   354/10000 [>.............................] - ETA: 24:30 - reward: -81.4064Episode 354 — Reward: 0.00, Length: 0
#   355/10000 [>.............................] - ETA: 24:32 - reward: -81.2883Episode 355 — Reward: 0.00, Length: 0
#   356/10000 [>.............................] - ETA: 24:34 - reward: -81.2040Episode 356 — Reward: 0.00, Length: 0
#   357/10000 [>.............................] - ETA: 24:35 - reward: -81.2728Episode 357 — Reward: 0.00, Length: 0
#   358/10000 [>.............................] - ETA: 24:36 - reward: -81.2473Episode 358 — Reward: 0.00, Length: 0
#   359/10000 [>.............................] - ETA: 24:37 - reward: -81.1085Episode 359 — Reward: 0.00, Length: 0
#   360/10000 [>.............................] - ETA: 24:38 - reward: -81.0354Episode 360 — Reward: 0.00, Length: 0
#   361/10000 [>.............................] - ETA: 24:39 - reward: -80.8949Episode 361 — Reward: 0.00, Length: 0
#   362/10000 [>.............................] - ETA: 24:42 - reward: -80.7659Episode 362 — Reward: 0.00, Length: 0
#   363/10000 [>.............................] - ETA: 24:49 - reward: -80.6279Episode 363 — Reward: 0.00, Length: 0
#   364/10000 [>.............................] - ETA: 24:52 - reward: -80.4525Episode 364 — Reward: 0.00, Length: 0
#   365/10000 [>.............................] - ETA: 24:55 - reward: -80.3150Episode 365 — Reward: 0.00, Length: 0
#   366/10000 [>.............................] - ETA: 24:58 - reward: -80.1692Episode 366 — Reward: 0.00, Length: 0
#   367/10000 [>.............................] - ETA: 25:02 - reward: -79.9928Episode 367 — Reward: 0.00, Length: 0
#   368/10000 [>.............................] - ETA: 25:06 - reward: -79.8916Episode 368 — Reward: 0.00, Length: 0
#   369/10000 [>.............................] - ETA: 25:10 - reward: -79.7899Episode 369 — Reward: 0.00, Length: 0
#   370/10000 [>.............................] - ETA: 25:11 - reward: -79.6976Episode 370 — Reward: 0.00, Length: 0
#   371/10000 [>.............................] - ETA: 25:12 - reward: -79.5819Episode 371 — Reward: 0.00, Length: 0
#   372/10000 [>.............................] - ETA: 25:12 - reward: -79.4091Episode 372 — Reward: 0.00, Length: 0
#   373/10000 [>.............................] - ETA: 25:13 - reward: -79.2380Episode 373 — Reward: 0.00, Length: 0
#   374/10000 [>.............................] - ETA: 25:16 - reward: -79.6385Episode 374 — Reward: 0.00, Length: 0
#   375/10000 [>.............................] - ETA: 25:16 - reward: -79.5747Episode 375 — Reward: 0.00, Length: 0
#   376/10000 [>.............................] - ETA: 25:17 - reward: -80.1698Episode 376 — Reward: 0.00, Length: 0
#   377/10000 [>.............................] - ETA: 25:18 - reward: -80.1508Episode 377 — Reward: 0.00, Length: 0
#   378/10000 [>.............................] - ETA: 25:19 - reward: -79.9773Episode 378 — Reward: 0.00, Length: 0
#   379/10000 [>.............................] - ETA: 25:20 - reward: -79.8197Episode 379 — Reward: 0.00, Length: 0
#   380/10000 [>.............................] - ETA: 25:21 - reward: -80.0821Episode 380 — Reward: 0.00, Length: 0
#   381/10000 [>.............................] - ETA: 25:22 - reward: -79.9180Episode 381 — Reward: 0.00, Length: 0
#   382/10000 [>.............................] - ETA: 25:23 - reward: -79.8689Episode 382 — Reward: 0.00, Length: 0
#   383/10000 [>.............................] - ETA: 25:24 - reward: -79.7305Episode 383 — Reward: 0.00, Length: 0
#   384/10000 [>.............................] - ETA: 25:26 - reward: -79.7424Episode 384 — Reward: 0.00, Length: 0
#   385/10000 [>.............................] - ETA: 25:27 - reward: -79.5818Episode 385 — Reward: 0.00, Length: 0
#   386/10000 [>.............................] - ETA: 25:27 - reward: -79.4142Episode 386 — Reward: 0.00, Length: 0
#   387/10000 [>.............................] - ETA: 25:28 - reward: -79.5944Episode 387 — Reward: 0.00, Length: 0
#   388/10000 [>.............................] - ETA: 25:31 - reward: -79.4913Episode 388 — Reward: 0.00, Length: 0
#   389/10000 [>.............................] - ETA: 25:31 - reward: -79.3678Episode 389 — Reward: 0.00, Length: 0
#   390/10000 [>.............................] - ETA: 25:32 - reward: -79.2445Episode 390 — Reward: 0.00, Length: 0
#   391/10000 [>.............................] - ETA: 25:33 - reward: -79.2161Episode 391 — Reward: 0.00, Length: 0
#   392/10000 [>.............................] - ETA: 25:34 - reward: -79.2391Episode 392 — Reward: 0.00, Length: 0
#   393/10000 [>.............................] - ETA: 25:37 - reward: -79.3102Episode 393 — Reward: 0.00, Length: 0
#   394/10000 [>.............................] - ETA: 25:37 - reward: -79.1469Episode 394 — Reward: 0.00, Length: 0
#   395/10000 [>.............................] - ETA: 25:38 - reward: -79.0250Episode 395 — Reward: 0.00, Length: 0
#   396/10000 [>.............................] - ETA: 25:44 - reward: -78.8645Episode 396 — Reward: 0.00, Length: 0
#   397/10000 [>.............................] - ETA: 25:46 - reward: -78.7423Episode 397 — Reward: 0.00, Length: 0
#   398/10000 [>.............................] - ETA: 25:47 - reward: -78.8271Episode 398 — Reward: 0.00, Length: 0
#   399/10000 [>.............................] - ETA: 25:48 - reward: -78.6752Episode 399 — Reward: 0.00, Length: 0
#   400/10000 [>.............................] - ETA: 25:48 - reward: -78.5532Episode 400 — Reward: 0.00, Length: 0
#   401/10000 [>.............................] - ETA: 25:51 - reward: -78.4489Episode 401 — Reward: 0.00, Length: 0
#   402/10000 [>.............................] - ETA: 25:53 - reward: -78.5233Episode 402 — Reward: 0.00, Length: 0
#   403/10000 [>.............................] - ETA: 25:54 - reward: -78.4271Episode 403 — Reward: 0.00, Length: 0
#   404/10000 [>.............................] - ETA: 25:54 - reward: -78.4212Episode 404 — Reward: 0.00, Length: 0
#   405/10000 [>.............................] - ETA: 25:55 - reward: -78.2653Episode 405 — Reward: 0.00, Length: 0
#   406/10000 [>.............................] - ETA: 25:58 - reward: -78.1774Episode 406 — Reward: 0.00, Length: 0
#   407/10000 [>.............................] - ETA: 25:58 - reward: -78.7491Episode 407 — Reward: 0.00, Length: 0
#   408/10000 [>.............................] - ETA: 25:59 - reward: -78.6627Episode 408 — Reward: 0.00, Length: 0
#   409/10000 [>.............................] - ETA: 26:00 - reward: -78.7371Episode 409 — Reward: 0.00, Length: 0
#   410/10000 [>.............................] - ETA: 26:03 - reward: -78.6184Episode 410 — Reward: 0.00, Length: 0
#   411/10000 [>.............................] - ETA: 26:05 - reward: -78.5017Episode 411 — Reward: 0.00, Length: 0
#   412/10000 [>.............................] - ETA: 26:05 - reward: -78.6225Episode 412 — Reward: 0.00, Length: 0
#   413/10000 [>.............................] - ETA: 26:06 - reward: -78.7840Episode 413 — Reward: 0.00, Length: 0
#   414/10000 [>.............................] - ETA: 26:07 - reward: -78.8685Episode 414 — Reward: 0.00, Length: 0
#   415/10000 [>.............................] - ETA: 26:12 - reward: -78.9394Episode 415 — Reward: 0.00, Length: 0
#   416/10000 [>.............................] - ETA: 26:15 - reward: -78.7871Episode 416 — Reward: 0.00, Length: 0
#   417/10000 [>.............................] - ETA: 26:18 - reward: -78.6375Episode 417 — Reward: 0.00, Length: 0
#   418/10000 [>.............................] - ETA: 26:24 - reward: -78.5884Episode 418 — Reward: 0.00, Length: 0
#   419/10000 [>.............................] - ETA: 26:27 - reward: -78.7575Episode 419 — Reward: 0.00, Length: 0
#   420/10000 [>.............................] - ETA: 26:30 - reward: -78.7084Episode 420 — Reward: 0.00, Length: 0
#   421/10000 [>.............................] - ETA: 26:33 - reward: -78.6336Episode 421 — Reward: 0.00, Length: 0
#   422/10000 [>.............................] - ETA: 26:33 - reward: -78.4847Episode 422 — Reward: 0.00, Length: 0
#   423/10000 [>.............................] - ETA: 26:34 - reward: -78.3868Episode 423 — Reward: 0.00, Length: 0
#   424/10000 [>.............................] - ETA: 26:35 - reward: -78.2669Episode 424 — Reward: 0.00, Length: 0
#   425/10000 [>.............................] - ETA: 26:37 - reward: -78.3473Episode 425 — Reward: 0.00, Length: 0
#   426/10000 [>.............................] - ETA: 26:38 - reward: -78.3402Episode 426 — Reward: 0.00, Length: 0
#   427/10000 [>.............................] - ETA: 26:39 - reward: -78.2812Episode 427 — Reward: 0.00, Length: 0
#   428/10000 [>.............................] - ETA: 26:39 - reward: -78.1641Episode 428 — Reward: 0.00, Length: 0
#   429/10000 [>.............................] - ETA: 26:42 - reward: -78.0231Episode 429 — Reward: 0.00, Length: 0
#   430/10000 [>.............................] - ETA: 26:43 - reward: -77.9202Episode 430 — Reward: 0.00, Length: 0
#   431/10000 [>.............................] - ETA: 26:44 - reward: -77.8464Episode 431 — Reward: 0.00, Length: 0
#   432/10000 [>.............................] - ETA: 26:44 - reward: -77.9626Episode 432 — Reward: 0.00, Length: 0
#   433/10000 [>.............................] - ETA: 26:45 - reward: -77.8896Episode 433 — Reward: 0.00, Length: 0
#   434/10000 [>.............................] - ETA: 26:47 - reward: -77.8240Episode 434 — Reward: 0.00, Length: 0
#   435/10000 [>.............................] - ETA: 26:48 - reward: -77.6787Episode 435 — Reward: 0.00, Length: 0
#   436/10000 [>.............................] - ETA: 26:48 - reward: -77.5381Episode 436 — Reward: 0.00, Length: 0
#   437/10000 [>.............................] - ETA: 26:49 - reward: -77.4576Episode 437 — Reward: 0.00, Length: 0
#   438/10000 [>.............................] - ETA: 26:50 - reward: -77.3722Episode 438 — Reward: 0.00, Length: 0
#   439/10000 [>.............................] - ETA: 26:51 - reward: -77.5473Episode 439 — Reward: 0.00, Length: 0
#   440/10000 [>.............................] - ETA: 26:52 - reward: -77.4399Episode 440 — Reward: 0.00, Length: 0
#   441/10000 [>.............................] - ETA: 26:53 - reward: -77.3557Episode 441 — Reward: 0.00, Length: 0
#   442/10000 [>.............................] - ETA: 26:54 - reward: -77.2494Episode 442 — Reward: 0.00, Length: 0
#   443/10000 [>.............................] - ETA: 26:55 - reward: -77.2000Episode 443 — Reward: 0.00, Length: 0
#   444/10000 [>.............................] - ETA: 26:56 - reward: -77.1000Episode 444 — Reward: 0.00, Length: 0
#   445/10000 [>.............................] - ETA: 26:57 - reward: -77.9881Episode 445 — Reward: 0.00, Length: 0
#   446/10000 [>.............................] - ETA: 26:57 - reward: -77.9054Episode 446 — Reward: 0.00, Length: 0
#   447/10000 [>.............................] - ETA: 27:00 - reward: -77.9302Episode 447 — Reward: 0.00, Length: 0
#   448/10000 [>.............................] - ETA: 27:01 - reward: -77.8823Episode 448 — Reward: 0.00, Length: 0
#   449/10000 [>.............................] - ETA: 27:04 - reward: -78.3581Episode 449 — Reward: 0.00, Length: 0
#   450/10000 [>.............................] - ETA: 27:05 - reward: -78.3035Episode 450 — Reward: 0.00, Length: 0
#   451/10000 [>.............................] - ETA: 27:05 - reward: -78.1910Episode 451 — Reward: 0.00, Length: 0
#   452/10000 [>.............................] - ETA: 27:06 - reward: -78.0623Episode 452 — Reward: 0.00, Length: 0
#   453/10000 [>.............................] - ETA: 27:06 - reward: -78.0866Episode 453 — Reward: 0.00, Length: 0
#   454/10000 [>.............................] - ETA: 27:07 - reward: -77.9980Episode 454 — Reward: 0.00, Length: 0
#   455/10000 [>.............................] - ETA: 27:08 - reward: -77.9012Episode 455 — Reward: 0.00, Length: 0
#   456/10000 [>.............................] - ETA: 27:10 - reward: -77.9007Episode 456 — Reward: 0.00, Length: 0
#   457/10000 [>.............................] - ETA: 27:10 - reward: -77.7959Episode 457 — Reward: 0.00, Length: 0
#   458/10000 [>.............................] - ETA: 27:11 - reward: -77.7860Episode 458 — Reward: 0.00, Length: 0
#   459/10000 [>.............................] - ETA: 27:12 - reward: -77.8067Episode 459 — Reward: 0.00, Length: 0
# ...
#   861/10000 [=>............................] - ETA: 36:05 - reward: -79.8589Episode 861 — Reward: 0.00, Length: 0
#   862/10000 [=>............................] - ETA: 36:07 - reward: -79.7840Episode 862 — Reward: 0.00, Length: 0
#   863/10000 [=>............................] - ETA: 36:08 - reward: -79.7110Episode 863 — Reward: 0.00, Length: 0
#   864/10000 [=>............................] - ETA: 36:08 - reward: -79.6603Episode 864 — Reward: 0.00, Length: 0
#   865/10000 [=>............................] - ETA: 36:09 - reward: -79.6245Episode 865 — Reward: 0.00, Length: 0
#   866/10000 [=>............................] - ETA: 36:09 - reward: -79.8118Episode 866 — Reward: 0.00, Length: 0
#   867/10000 [=>............................] - ETA: 36:11 - reward: -79.7362Episode 867 — Reward: 0.00, Length: 0
#   868/10000 [=>............................] - ETA: 36:11 - reward: -79.7457Episode 868 — Reward: 0.00, Length: 0
#   869/10000 [=>............................] - ETA: 36:12 - reward: -79.7031Episode 869 — Reward: 0.00, Length: 0
#   870/10000 [=>............................] - ETA: 36:13 - reward: -79.6436Episode 870 — Reward: 0.00, Length: 0
#   871/10000 [=>............................] - ETA: 36:13 - reward: -79.5912Episode 871 — Reward: 0.00, Length: 0
#   872/10000 [=>............................] - ETA: 36:14 - reward: -79.5232Episode 872 — Reward: 0.00, Length: 0
#   873/10000 [=>............................] - ETA: 36:15 - reward: -79.4508Episode 873 — Reward: 0.00, Length: 0
#   874/10000 [=>............................] - ETA: 36:16 - reward: -79.3883Episode 874 — Reward: 0.00, Length: 0
#   875/10000 [=>............................] - ETA: 36:17 - reward: -79.3151Episode 875 — Reward: 0.00, Length: 0
#   876/10000 [=>............................] - ETA: 36:18 - reward: -79.3315Episode 876 — Reward: 0.00, Length: 0
#   877/10000 [=>............................] - ETA: 36:19 - reward: -79.2926Episode 877 — Reward: 0.00, Length: 0
#   878/10000 [=>............................] - ETA: 36:21 - reward: -79.2381Episode 878 — Reward: 0.00, Length: 0
#   879/10000 [=>............................] - ETA: 36:22 - reward: -79.1825Episode 879 — Reward: 0.00, Length: 0
#   880/10000 [=>............................] - ETA: 36:22 - reward: -79.1449Episode 880 — Reward: 0.00, Length: 0
#   881/10000 [=>............................] - ETA: 36:24 - reward: -79.2148Episode 881 — Reward: 0.00, Length: 0
#   882/10000 [=>............................] - ETA: 36:25 - reward: -79.1721Episode 882 — Reward: 0.00, Length: 0
#   883/10000 [=>............................] - ETA: 36:25 - reward: -79.1198Episode 883 — Reward: 0.00, Length: 0
#   884/10000 [=>............................] - ETA: 36:26 - reward: -79.1269Episode 884 — Reward: 0.00, Length: 0
#   885/10000 [=>............................] - ETA: 36:27 - reward: -79.2017Episode 885 — Reward: 0.00, Length: 0
#   886/10000 [=>............................] - ETA: 36:28 - reward: -79.1656Episode 886 — Reward: 0.00, Length: 0
#   887/10000 [=>............................] - ETA: 36:29 - reward: -79.1108Episode 887 — Reward: 0.00, Length: 0
#   888/10000 [=>............................] - ETA: 36:30 - reward: -79.3673Episode 888 — Reward: 0.00, Length: 0
#   889/10000 [=>............................] - ETA: 36:31 - reward: -79.3152Episode 889 — Reward: 0.00, Length: 0
#   890/10000 [=>............................] - ETA: 36:32 - reward: -79.5363Episode 890 — Reward: 0.00, Length: 0
#   891/10000 [=>............................] - ETA: 36:35 - reward: -79.4693Episode 891 — Reward: 0.00, Length: 0
#   892/10000 [=>............................] - ETA: 36:39 - reward: -79.4143Episode 892 — Reward: 0.00, Length: 0
#   893/10000 [=>............................] - ETA: 36:41 - reward: -79.3441Episode 893 — Reward: 0.00, Length: 0
#   894/10000 [=>............................] - ETA: 36:45 - reward: -79.3030Episode 894 — Reward: 0.00, Length: 0
#   895/10000 [=>............................] - ETA: 36:45 - reward: -79.2811Episode 895 — Reward: 0.00, Length: 0
#   896/10000 [=>............................] - ETA: 36:49 - reward: -79.3133Episode 896 — Reward: 0.00, Length: 0
#   897/10000 [=>............................] - ETA: 36:50 - reward: -79.2587Episode 897 — Reward: 0.00, Length: 0
#   898/10000 [=>............................] - ETA: 36:51 - reward: -79.2043Episode 898 — Reward: 0.00, Length: 0
#   899/10000 [=>............................] - ETA: 36:52 - reward: -79.1452Episode 899 — Reward: 0.00, Length: 0
#   900/10000 [=>............................] - ETA: 36:52 - reward: -79.0920Episode 900 — Reward: 0.00, Length: 0
#   901/10000 [=>............................] - ETA: 36:53 - reward: -79.1511Episode 901 — Reward: 0.00, Length: 0
#   902/10000 [=>............................] - ETA: 36:54 - reward: -79.1053Episode 902 — Reward: 0.00, Length: 0
#   903/10000 [=>............................] - ETA: 36:55 - reward: -79.0469Episode 903 — Reward: 0.00, Length: 0
#   904/10000 [=>............................] - ETA: 36:55 - reward: -78.9951Episode 904 — Reward: 0.00, Length: 0
#   905/10000 [=>............................] - ETA: 36:56 - reward: -78.9597Episode 905 — Reward: 0.00, Length: 0
#   906/10000 [=>............................] - ETA: 36:57 - reward: -78.9005Episode 906 — Reward: 0.00, Length: 0
#   907/10000 [=>............................] - ETA: 36:58 - reward: -78.9357Episode 907 — Reward: 0.00, Length: 0
#   908/10000 [=>............................] - ETA: 36:59 - reward: -78.8968Episode 908 — Reward: 0.00, Length: 0
#   909/10000 [=>............................] - ETA: 37:00 - reward: -78.8669Episode 909 — Reward: 0.00, Length: 0
#   910/10000 [=>............................] - ETA: 37:01 - reward: -78.8235Episode 910 — Reward: 0.00, Length: 0
#   911/10000 [=>............................] - ETA: 37:01 - reward: -78.7715Episode 911 — Reward: 0.00, Length: 0
#   912/10000 [=>............................] - ETA: 37:03 - reward: -78.8037Episode 912 — Reward: 0.00, Length: 0
#   913/10000 [=>............................] - ETA: 37:03 - reward: -78.7901Episode 913 — Reward: 0.00, Length: 0
#   914/10000 [=>............................] - ETA: 37:04 - reward: -78.7351Episode 914 — Reward: 0.00, Length: 0
#   915/10000 [=>............................] - ETA: 37:05 - reward: -78.6654Episode 915 — Reward: 0.00, Length: 0
#   916/10000 [=>............................] - ETA: 37:06 - reward: -78.6079Episode 916 — Reward: 0.00, Length: 0
#   917/10000 [=>............................] - ETA: 37:07 - reward: -78.5400Episode 917 — Reward: 0.00, Length: 0
#   918/10000 [=>............................] - ETA: 37:08 - reward: -78.4733Episode 918 — Reward: 0.00, Length: 0
#   919/10000 [=>............................] - ETA: 37:09 - reward: -78.4371Episode 919 — Reward: 0.00, Length: 0
#   920/10000 [=>............................] - ETA: 37:10 - reward: -78.3865Episode 920 — Reward: 0.00, Length: 0
#   921/10000 [=>............................] - ETA: 37:11 - reward: -78.3403Episode 921 — Reward: 0.00, Length: 0
#   922/10000 [=>............................] - ETA: 37:11 - reward: -79.1800Episode 922 — Reward: 0.00, Length: 0
#   923/10000 [=>............................] - ETA: 37:14 - reward: -79.2888Episode 923 — Reward: 0.00, Length: 0
#   924/10000 [=>............................] - ETA: 37:16 - reward: -79.2901Episode 924 — Reward: 0.00, Length: 0
#   925/10000 [=>............................] - ETA: 37:19 - reward: -79.2532Episode 925 — Reward: 0.00, Length: 0
#   926/10000 [=>............................] - ETA: 37:22 - reward: -79.2082Episode 926 — Reward: 0.00, Length: 0
#   927/10000 [=>............................] - ETA: 37:23 - reward: -79.1439Episode 927 — Reward: 0.00, Length: 0
#   928/10000 [=>............................] - ETA: 37:24 - reward: -79.0908Episode 928 — Reward: 0.00, Length: 0
#   929/10000 [=>............................] - ETA: 37:24 - reward: -79.0578Episode 929 — Reward: 0.00, Length: 0
#   930/10000 [=>............................] - ETA: 37:26 - reward: -78.9886Episode 930 — Reward: 0.00, Length: 0
#   931/10000 [=>............................] - ETA: 37:26 - reward: -78.9330Episode 931 — Reward: 0.00, Length: 0
#   932/10000 [=>............................] - ETA: 37:27 - reward: -78.8642Episode 932 — Reward: 0.00, Length: 0
#   933/10000 [=>............................] - ETA: 37:28 - reward: -78.8532Episode 933 — Reward: 0.00, Length: 0
#   934/10000 [=>............................] - ETA: 37:29 - reward: -78.8007Episode 934 — Reward: 0.00, Length: 0
#   935/10000 [=>............................] - ETA: 37:30 - reward: -78.7322Episode 935 — Reward: 0.00, Length: 0
#   936/10000 [=>............................] - ETA: 37:31 - reward: -78.7056Episode 936 — Reward: 0.00, Length: 0
#   937/10000 [=>............................] - ETA: 37:32 - reward: -78.6552Episode 937 — Reward: 0.00, Length: 0
#   938/10000 [=>............................] - ETA: 37:33 - reward: -78.6068Episode 938 — Reward: 0.00, Length: 0
#   939/10000 [=>............................] - ETA: 37:33 - reward: -78.5591Episode 939 — Reward: 0.00, Length: 0
#   940/10000 [=>............................] - ETA: 37:35 - reward: -78.5195Episode 940 — Reward: 0.00, Length: 0
#   941/10000 [=>............................] - ETA: 37:35 - reward: -78.4650Episode 941 — Reward: 0.00, Length: 0
#   942/10000 [=>............................] - ETA: 37:36 - reward: -78.5174Episode 942 — Reward: 0.00, Length: 0
#   943/10000 [=>............................] - ETA: 37:37 - reward: -78.4514Episode 943 — Reward: 0.00, Length: 0
#   944/10000 [=>............................] - ETA: 37:38 - reward: -78.3960Episode 944 — Reward: 0.00, Length: 0
#   945/10000 [=>............................] - ETA: 37:39 - reward: -80.5398Episode 945 — Reward: 0.00, Length: 0
#   946/10000 [=>............................] - ETA: 37:40 - reward: -80.4819Episode 946 — Reward: 0.00, Length: 0
#   947/10000 [=>............................] - ETA: 37:40 - reward: -80.4179Episode 947 — Reward: 0.00, Length: 0
#   948/10000 [=>............................] - ETA: 37:41 - reward: -80.3722Episode 948 — Reward: 0.00, Length: 0
#   949/10000 [=>............................] - ETA: 37:42 - reward: -80.3246Episode 949 — Reward: 0.00, Length: 0
#   950/10000 [=>............................] - ETA: 37:43 - reward: -80.3171Episode 950 — Reward: 0.00, Length: 0
#   951/10000 [=>............................] - ETA: 37:43 - reward: -80.2681Episode 951 — Reward: 0.00, Length: 0
#   952/10000 [=>............................] - ETA: 37:44 - reward: -80.2290Episode 952 — Reward: 0.00, Length: 0
#   953/10000 [=>............................] - ETA: 37:44 - reward: -80.1804Episode 953 — Reward: 0.00, Length: 0
#   954/10000 [=>............................] - ETA: 37:46 - reward: -80.1352Episode 954 — Reward: 0.00, Length: 0
#   955/10000 [=>............................] - ETA: 37:48 - reward: -80.0840Episode 955 — Reward: 0.00, Length: 0
#   956/10000 [=>............................] - ETA: 37:51 - reward: -80.0770Episode 956 — Reward: 0.00, Length: 0
#   957/10000 [=>............................] - ETA: 37:54 - reward: -80.3526Episode 957 — Reward: 0.00, Length: 0
#   958/10000 [=>............................] - ETA: 37:56 - reward: -80.3070Episode 958 — Reward: 0.00, Length: 0
#   959/10000 [=>............................] - ETA: 37:57 - reward: -80.2510Episode 959 — Reward: 0.00, Length: 0
#   960/10000 [=>............................] - ETA: 37:57 - reward: -80.1850Episode 960 — Reward: 0.00, Length: 0
#   961/10000 [=>............................] - ETA: 37:57 - reward: -80.2568Episode 961 — Reward: 0.00, Length: 0
#   962/10000 [=>............................] - ETA: 37:58 - reward: -80.2535Episode 962 — Reward: 0.00, Length: 0
#   963/10000 [=>............................] - ETA: 37:58 - reward: -80.2064Episode 963 — Reward: 0.00, Length: 0
#   964/10000 [=>............................] - ETA: 37:59 - reward: -80.1844Episode 964 — Reward: 0.00, Length: 0
#   965/10000 [=>............................] - ETA: 38:00 - reward: -80.1422Episode 965 — Reward: 0.00, Length: 0
#   966/10000 [=>............................] - ETA: 38:01 - reward: -80.1032Episode 966 — Reward: 0.00, Length: 0
#   967/10000 [=>............................] - ETA: 38:01 - reward: -80.0405Episode 967 — Reward: 0.00, Length: 0
#   968/10000 [=>............................] - ETA: 38:02 - reward: -79.9969Episode 968 — Reward: 0.00, Length: 0
#   969/10000 [=>............................] - ETA: 38:03 - reward: -79.9744Episode 969 — Reward: 0.00, Length: 0
#   970/10000 [=>............................] - ETA: 38:04 - reward: -79.9543Episode 970 — Reward: 0.00, Length: 0
#   971/10000 [=>............................] - ETA: 38:04 - reward: -79.9185Episode 971 — Reward: 0.00, Length: 0
#   972/10000 [=>............................] - ETA: 38:05 - reward: -79.8715Episode 972 — Reward: 0.00, Length: 0
#   973/10000 [=>............................] - ETA: 38:06 - reward: -79.9063Episode 973 — Reward: 0.00, Length: 0
#   974/10000 [=>............................] - ETA: 38:06 - reward: -79.8725Episode 974 — Reward: 0.00, Length: 0
#   975/10000 [=>............................] - ETA: 38:07 - reward: -79.8134Episode 975 — Reward: 0.00, Length: 0
#   976/10000 [=>............................] - ETA: 38:08 - reward: -79.8195Episode 976 — Reward: 0.00, Length: 0
#   977/10000 [=>............................] - ETA: 38:09 - reward: -79.7755Episode 977 — Reward: 0.00, Length: 0
#   978/10000 [=>............................] - ETA: 38:10 - reward: -79.7141Episode 978 — Reward: 0.00, Length: 0
#   979/10000 [=>............................] - ETA: 38:10 - reward: -79.6496Episode 979 — Reward: 0.00, Length: 0
#   980/10000 [=>............................] - ETA: 38:11 - reward: -79.5949Episode 980 — Reward: 0.00, Length: 0
#   981/10000 [=>............................] - ETA: 38:12 - reward: -79.5549Episode 981 — Reward: 0.00, Length: 0
#   982/10000 [=>............................] - ETA: 38:12 - reward: -79.4907Episode 982 — Reward: 0.00, Length: 0
#   983/10000 [=>............................] - ETA: 38:13 - reward: -79.5363Episode 983 — Reward: 0.00, Length: 0
#   984/10000 [=>............................] - ETA: 38:14 - reward: -79.4719Episode 984 — Reward: 0.00, Length: 0
#   985/10000 [=>............................] - ETA: 38:14 - reward: -79.4069Episode 985 — Reward: 0.00, Length: 0
#   986/10000 [=>............................] - ETA: 38:16 - reward: -79.3422Episode 986 — Reward: 0.00, Length: 0
#   987/10000 [=>............................] - ETA: 38:18 - reward: -79.3968Episode 987 — Reward: 0.00, Length: 0
#   988/10000 [=>............................] - ETA: 38:21 - reward: -79.3654Episode 988 — Reward: 0.00, Length: 0
#   989/10000 [=>............................] - ETA: 38:25 - reward: -79.3120Episode 989 — Reward: 0.00, Length: 0
#   990/10000 [=>............................] - ETA: 38:26 - reward: -79.2520Episode 990 — Reward: 0.00, Length: 0
#   991/10000 [=>............................] - ETA: 38:26 - reward: -79.2110Episode 991 — Reward: 0.00, Length: 0
#   992/10000 [=>............................] - ETA: 38:27 - reward: -79.2161Episode 992 — Reward: 0.00, Length: 0
#   993/10000 [=>............................] - ETA: 38:28 - reward: -79.1528Episode 993 — Reward: 0.00, Length: 0
#   994/10000 [=>............................] - ETA: 38:28 - reward: -79.0881Episode 994 — Reward: 0.00, Length: 0
#   995/10000 [=>............................] - ETA: 38:29 - reward: -79.0567Episode 995 — Reward: 0.00, Length: 0
#   996/10000 [=>............................] - ETA: 38:30 - reward: -79.0061Episode 996 — Reward: 0.00, Length: 0
#   997/10000 [=>............................] - ETA: 38:33 - reward: -78.9734Episode 997 — Reward: 0.00, Length: 0
#   998/10000 [=>............................] - ETA: 38:34 - reward: -78.9318Episode 998 — Reward: 0.00, Length: 0
#   999/10000 [=>............................] - ETA: 38:34 - reward: -78.8781Episode 999 — Reward: 0.00, Length: 0
#  1000/10000 [==>...........................] - ETA: 38:35 - reward: -78.8147Episode 1000 — Reward: 0.00, Length: 0
# done, took 257.524 seconds

# %%
scores = agent.test(env, nb_episodes=100, visualize=False)
print("Average reward:", np.mean(scores.history['episode_reward']))

# %%
# !tensorboard --logdir=logs/
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.12.3 at http://localhost:6006/ (Press CTRL+C to quit)

# %%
env = HospitalEnv(data)
state = env.reset()
print("State shape:", state.shape)  # Should be (2,)
print("State values:", state)

# %%
test_obs = env.reset()
action = agent.forward(test_obs)
print(f"Recommended Department: {label_encoders['MDC'].inverse_transform([action])}")
# Out:
# Recommended Department: ['-1 – Fehler-DRGs und sonstige DRGs']

# %%
print(action)
# Out:
# 0

# %%
test_obs
# Out:
# array([-3.76531171e-01, -7.32338210e-01,  0.00000000e+00, -2.60453945e-01,
#        -3.10989198e-01, -3.68211224e-01, -3.79477048e-01, -3.70607302e-01,
#        -2.27952683e-01,  0.00000000e+00, -2.58048029e-01, -1.74568155e-01,
#         0.00000000e+00, -4.15203161e-01, -5.52554378e-01,  1.28879938e-01,
#        -6.41573236e-01, -4.92773149e-01, -4.73003138e-01, -2.58048029e-01,
#        -4.39866705e-01, -6.35515538e-01, -3.56381239e-01,  0.00000000e+00,
#         0.00000000e+00, -2.58593843e-01, -2.60453945e-01, -2.79881305e-01,
#         0.00000000e+00, -4.49100812e-01, -5.57180382e-01,  2.62779536e+00,
#         0.00000000e+00, -2.81105087e-01,  0.00000000e+00, -4.48640038e-01,
#        -4.77500735e-01, -2.59974094e-01,  1.62177144e-01, -6.72884606e-01,
#         0.00000000e+00, -4.03260401e-01, -6.57933451e-01, -5.71902651e-01,
#        -3.38856528e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -3.84030765e-01,  0.00000000e+00,
#         0.00000000e+00, -1.81122693e-01,  0.00000000e+00, -3.06545199e-01,
#         0.00000000e+00, -2.08233278e-01, -3.34432924e-01, -6.44194783e-01,
#        -4.63892914e-01, -6.74220515e-01, -4.49135111e-01, -3.47653924e-01,
#        -3.53988015e-01, -3.79618592e-01,  3.84888352e-01, -4.85408955e-01,
#        -2.59974094e-01,  0.00000000e+00, -6.70616650e-01, -6.11013049e-01,
#         4.92039076e-01, -7.39532036e-01, -2.33929846e-01, -7.75953742e-01,
#        -2.58048029e-01, -7.45246377e-01, -2.57239990e-01, -1.18335519e-02,
#        -3.47426429e-01, -8.76996810e-03, -7.90211687e-01, -3.71310529e-01,
#        -6.32396186e-01, -3.15181617e-01, -5.51581541e-01, -7.43189335e-01,
#        -3.83058324e-01, -5.03009358e-02, -3.31346257e-01, -3.33399724e-02,
#        -2.65943338e-01, -5.06205659e-01, -4.63186989e-01, -5.73437164e-01,
#         0.00000000e+00,  0.00000000e+00, -8.45011759e-01, -6.44960905e-01,
#        -4.70809984e-01,  1.06961438e+00, -3.68184278e-01, -4.49091091e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -7.86723240e-01,
#        -7.84722346e-01, -8.47358168e-01, -4.11440707e-01,  0.00000000e+00,
#         0.00000000e+00, -9.09050986e-01, -1.59568553e-01, -3.81014570e-01,
#         0.00000000e+00, -2.58367860e-01, -6.18778937e-01,  1.94728614e-01,
#         0.00000000e+00,  0.00000000e+00, -7.94626823e-01,  2.29764965e-01,
#         0.00000000e+00,  0.00000000e+00, -8.74941342e-01, -8.75040105e-01,
#         9.75110922e-02, -6.74010873e-01,  0.00000000e+00, -4.18332909e-01,
#         3.87356423e-01, -3.76531171e-01, -7.32338210e-01,  0.00000000e+00,
#        -2.60453945e-01, -3.10989198e-01, -3.68211224e-01, -3.79477048e-01,
#        -3.70607302e-01, -2.27952683e-01,  0.00000000e+00, -2.58048029e-01,
#        -8.61891804e-01,  0.00000000e+00, -1.74568155e-01, -4.75961606e-01,
#         0.00000000e+00, -5.80785729e-01,  0.00000000e+00, -6.22029780e-01,
#         7.36097015e-01,  0.00000000e+00, -5.86134286e-01, -2.50587894e-01,
#        -4.15203161e-01, -5.52554378e-01,  1.28879938e-01, -6.41573236e-01,
#        -4.92773149e-01, -4.73003138e-01, -2.58048029e-01, -4.39866705e-01,
#        -6.35515538e-01, -6.29047679e-01, -2.54113639e-01, -7.13294538e-01,
#         0.00000000e+00, -7.23551685e-01, -1.46947091e-01, -9.95241578e-01,
#         0.00000000e+00, -8.21939580e-01,  0.00000000e+00, -3.56381239e-01,
#         0.00000000e+00,  0.00000000e+00, -7.02653871e-01, -1.98875456e-01,
#        -2.58593843e-01, -2.60453945e-01, -2.79881305e-01,  0.00000000e+00,
#        -4.36644858e-01, -3.73359745e-01, -2.76969041e-01, -3.70515948e-01,
#        -4.49100812e-01, -5.57180382e-01,  2.62779536e+00, -5.62244113e-01,
#        -5.66156650e-01,  0.00000000e+00, -2.81105087e-01,  0.00000000e+00,
#        -4.48640038e-01, -7.64532538e-01,  0.00000000e+00, -5.31574376e-01,
#        -7.07685744e-01, -7.04790036e-01,  5.19180567e+00, -5.50980678e-01,
#        -5.43421901e-01, -4.77500735e-01, -2.59974094e-01,  1.62177144e-01,
#        -6.72884606e-01, -5.42403840e-01, -4.22132450e-01,  0.00000000e+00,
#        -4.03260401e-01, -6.57933451e-01, -5.71902651e-01, -3.38856528e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -3.84556336e-01,
#        -4.01378121e-01,  0.00000000e+00,  0.00000000e+00, -4.74889534e-01,
#        -3.87445101e-01, -3.84030765e-01,  0.00000000e+00,  0.00000000e+00,
#        -7.09132166e-02,  0.00000000e+00, -1.81122693e-01, -1.23122813e-01,
#         0.00000000e+00,  0.00000000e+00, -3.06545199e-01, -1.84475634e-01,
#        -4.76376556e-01,  0.00000000e+00, -4.80699114e-01,  0.00000000e+00,
#         4.23947755e-01,  0.00000000e+00, -2.08233278e-01, -3.34432924e-01,
#        -6.44194783e-01, -4.63892914e-01, -6.74220515e-01, -4.49135111e-01,
#        -3.47653924e-01, -3.53988015e-01, -3.79618592e-01,  3.84888352e-01,
#        -4.85408955e-01, -2.59974094e-01,  0.00000000e+00, -9.82148295e-01,
#        -6.96395037e-01, -6.70616650e-01, -6.11013049e-01,  4.92039076e-01,
#        -7.39532036e-01, -2.33929846e-01, -7.75953742e-01, -2.58048029e-01,
#        -7.45246377e-01, -2.57239990e-01, -1.18335519e-02, -3.47426429e-01,
#        -8.76996810e-03, -7.90211687e-01, -3.71310529e-01, -5.40700021e-01,
#        -5.04281298e-01, -3.12151730e-01,  1.22369835e+00,  1.50000000e+01,
#         1.50000000e+01, -3.12151730e-01])
